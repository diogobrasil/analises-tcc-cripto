# %%
import os
import sys
sys.path.append(os.path.abspath("../../.."))

import pandas as pd
import matplotlib.pyplot as plt

from classes.neural_networks.training.train_arima import (
    train_and_evaluate_arima,
    load_series,
    split_series
)

# %%
# --- Parâmetros ---
csv_path   = "../../datasets/b3_dados/processed/acoes_concat.csv"
target     = "BRAP3"
order      = (2, 1, 1)
model_dir  = "../../saved_models/arima"
version    = "1.0"
train_end  = "2017-12-31"
val_end    = "2018-12-31"
rolling    = True
step_size  = 1

# %%
# --- Carrega dados e divide em train/val/test ---
ts    = load_series(csv_path, target)
train, val, test = split_series(ts, train_end, val_end)

# --- Treina e avalia ---
result = train_and_evaluate_arima(
    csv_path=csv_path,
    target=target,
    order=order,
    model_dir=model_dir,
    version=version,
    train_end=train_end,
    val_end=val_end,
    rolling=rolling,
    step_size=step_size
)

metrics     = result["metrics"]
predictions = result["predictions"]
train_pred  = predictions["train"]
val_pred    = predictions["val"]
test_pred   = predictions["test"]

# --- Exibe métricas ---
print("=== TRAIN METRICS ===")
for name, val in metrics["train"].items():
    print(f"{name}: {val:.4f}")

print("\n=== VAL METRICS ===")
for name, val in metrics["val"].items():
    print(f"{name}: {val:.4f}")

print("\n=== TEST METRICS ===")
for name, val in metrics["test"].items():
    print(f"{name}: {val:.4f}")
# Out:
# 2025-06-22 15:55:05,558 - INFO - Loading series for target BRAP3
# 2025-06-22 15:55:05,775 - INFO - Split sizes → train: 1978, val: 245, test: 931
# c:\Users\mathi\.conda\envs\Project_data_mining\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\mathi\.conda\envs\Project_data_mining\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\mathi\.conda\envs\Project_data_mining\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\mathi\.conda\envs\Project_data_mining\lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\mathi\.conda\envs\Project_data_mining\lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\mathi\.conda\envs\Project_data_mining\lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\mathi\.conda\envs\Project_data_mining\lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\mathi\.conda\envs\Project_data_mining\lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\mathi\.conda\envs\Project_data_mining\lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 2025-06-22 15:55:16,165 - INFO -
# TRAIN metrics:
# 2025-06-22 15:55:16,165 - INFO -   MSE: 0.0113
# 2025-06-22 15:55:16,165 - INFO -   RMSE: 0.1062
# 2025-06-22 15:55:16,165 - INFO -   MAE: 0.0480
# 2025-06-22 15:55:16,180 - INFO -   R2: 0.9902
# 2025-06-22 15:55:16,180 - INFO -
# VAL metrics:
# 2025-06-22 15:55:16,180 - INFO -   MSE: 0.0175
# 2025-06-22 15:55:16,180 - INFO -   RMSE: 0.1323
# 2025-06-22 15:55:16,180 - INFO -   MAE: 0.0968
# 2025-06-22 15:55:16,180 - INFO -   R2: 0.8971
# 2025-06-22 15:55:16,180 - INFO -
# TEST metrics:
# 2025-06-22 15:55:16,180 - INFO -   MSE: 0.0843
# 2025-06-22 15:55:16,180 - INFO -   RMSE: 0.2904
# 2025-06-22 15:55:16,180 - INFO -   MAE: 0.2013
# 2025-06-22 15:55:16,195 - INFO -   R2: 0.9966
# 2025-06-22 15:55:16,336 - INFO - Artifacts saved under ..\..\saved_models\arima
# === TRAIN METRICS ===
# MSE: 0.0113
# RMSE: 0.1062
# MAE: 0.0480
# R2: 0.9902
#
# === VAL METRICS ===
# MSE: 0.0175
# RMSE: 0.1323
# MAE: 0.0968
# R2: 0.8971
#
# === TEST METRICS ===
# MSE: 0.0843
# RMSE: 0.2904
# MAE: 0.2013
# R2: 0.9966
